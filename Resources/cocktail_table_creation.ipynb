# %%
import pandas as pd

# %%
file_path = r"C:\Users\micha\Desktop\Data_Analytics\cocktails_output.csv"

df = pd.read_csv(file_path)


df.head()
# Out:
#    idDrink strDrink  strDrinkAlternate            strTags strVideo  \
# 0    17222       A1                NaN                NaN      NaN
# 1    13501      ABC                NaN                NaN      NaN
# 2    17225      Ace                NaN                NaN      NaN
# 3    14610     ACID                NaN                NaN      NaN
# 4    17837     Adam                NaN  Alcoholic,Holiday      NaN
#
#       strCategory strIBA strAlcoholic        strGlass  \
# 0        Cocktail    NaN    Alcoholic  Cocktail glass
# 1            Shot    NaN    Alcoholic      Shot glass
# 2        Cocktail    NaN    Alcoholic   Martini Glass
# 3            Shot    NaN    Alcoholic      Shot glass
# 4  Ordinary Drink    NaN    Alcoholic  Cocktail glass
#
#                                      strInstructions  ... strMeasure10  \
# 0  Pour all ingredients into a cocktail shaker, m...  ...          NaN
# 1                           Layered in a shot glass.  ...          NaN
# 2  Shake all the ingredients in a cocktail shaker...  ...          NaN
# 3  Poor in the 151 first followed by the 101 serv...  ...          NaN
# 4  In a shaker half-filled with ice cubes, combin...  ...          NaN
#
#   strMeasure11  strMeasure12 strMeasure13  strMeasure14  strMeasure15  \
# 0          NaN           NaN          NaN           NaN           NaN
# 1          NaN           NaN          NaN           NaN           NaN
# 2          NaN           NaN          NaN           NaN           NaN
# 3          NaN           NaN          NaN           NaN           NaN
# 4          NaN           NaN          NaN           NaN           NaN
#
#   strImageSource strImageAttribution strCreativeCommonsConfirmed  \
# 0            NaN                 NaN                          No
# 1            NaN                 NaN                          No
# 2            NaN                 NaN                          No
# 3            NaN                 NaN                          No
# 4            NaN                 NaN                         Yes
#
#        dateModified
# 0    9/7/2017 21:42
# 1   8/31/2016 19:32
# 2    9/7/2017 22:05
# 3  11/15/2016 11:28
# 4    9/2/2016 11:29
#
# [5 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['idDrink', 'strDrink', 'strDrinkAlternate', 'strTags', 'strVideo',
#        'strCategory', 'strIBA', 'strAlcoholic', 'strGlass', 'strInstructions',
#        'strInstructionsES', 'strInstructionsDE', 'strInstructionsFR',
#        'strInstructionsIT', 'strInstructionsZH-HANS', 'strInstructionsZH-HANT',
#        'strDrinkThumb', 'strIngredient1', 'strIngredient2', 'strIngredient3',
#        'strIngredient4', 'strIngredient5', 'strIngredient6', 'strIngredient7',
#        'strIngredient8', 'strIngredient9', 'strIngredient10',
#        'strIngredient11', 'strIngredient12', 'strIngredient13',
#        'strIngredient14', 'strIngredient15', 'strMeasure1', 'strMeasure2',
#        'strMeasure3', 'strMeasure4', 'strMeasure5', 'strMeasure6',
#        'strMeasure7', 'strMeasure8', 'strMeasure9', 'strMeasure10',
#        'strMeasure11', 'strMeasure12', 'strMeasure13', 'strMeasure14',
#        'strMeasure15', 'strImageSource', 'strImageAttribution',
#        'strCreativeCommonsConfirmed', 'dateModified'],
#       dtype='object')

# %%
drop_cols = ['strDrinkAlternate',
             'strVideo',
             'strIBA',
             'strInstructionsES',
             'strInstructionsDE',
             'strInstructionsFR',
             'strInstructionsIT',
             'strInstructionsZH-HANS',
             'strInstructionsZH-HANT',
             'strDrinkThumb',
             'strCreativeCommonsConfirmed',
             'strIngredient12',
             'strIngredient13',
             'strIngredient14',
             'strIngredient15',
             'strMeasure12',
             'strMeasure13',
             'strMeasure14',
             'strMeasure15',
             'strImageSource',
             'strImageAttribution']

df.drop(columns=drop_cols, inplace=True)

df.columns
# Out:
# Index(['idDrink', 'strDrink', 'strTags', 'strCategory', 'strAlcoholic',
#        'strGlass', 'strInstructions', 'strIngredient1', 'strIngredient2',
#        'strIngredient3', 'strIngredient4', 'strIngredient5', 'strIngredient6',
#        'strIngredient7', 'strIngredient8', 'strIngredient9', 'strIngredient10',
#        'strIngredient11', 'strMeasure1', 'strMeasure2', 'strMeasure3',
#        'strMeasure4', 'strMeasure5', 'strMeasure6', 'strMeasure7',
#        'strMeasure8', 'strMeasure9', 'strMeasure10', 'strMeasure11',
#        'dateModified'],
#       dtype='object')

# %%
measures_list = ['strMeasure1',
                 'strMeasure2',
                 'strMeasure3',
                 'strMeasure4',
                 'strMeasure5',
                 'strMeasure6',
                 'strMeasure7',
                 'strMeasure8',
                 'strMeasure9',
                 'strMeasure10',
                 'strMeasure11']


ingredients_list = ['strIngredient1',
                    'strIngredient2',
                    'strIngredient3',
                    'strIngredient4',
                    'strIngredient5',
                    'strIngredient6',
                    'strIngredient7',
                    'strIngredient8',
                    'strIngredient9',
                    'strIngredient10',
                    'strIngredient11']

cocktail_df_exclude_cols = measures_list + ingredients_list

#Cocktails DB
cocktails_df = df.drop(columns=cocktail_df_exclude_cols)
cocktails_df.head()
# Out:
#    idDrink strDrink            strTags     strCategory strAlcoholic  \
# 0    17222       A1                NaN        Cocktail    Alcoholic
# 1    13501      ABC                NaN            Shot    Alcoholic
# 2    17225      Ace                NaN        Cocktail    Alcoholic
# 3    14610     ACID                NaN            Shot    Alcoholic
# 4    17837     Adam  Alcoholic,Holiday  Ordinary Drink    Alcoholic
#
#          strGlass                                    strInstructions  \
# 0  Cocktail glass  Pour all ingredients into a cocktail shaker, m...
# 1      Shot glass                           Layered in a shot glass.
# 2   Martini Glass  Shake all the ingredients in a cocktail shaker...
# 3      Shot glass  Poor in the 151 first followed by the 101 serv...
# 4  Cocktail glass  In a shaker half-filled with ice cubes, combin...
#
#        dateModified
# 0    9/7/2017 21:42
# 1   8/31/2016 19:32
# 2    9/7/2017 22:05
# 3  11/15/2016 11:28
# 4    9/2/2016 11:29

# %%
#Cocktails DB
cocktails_df = df.drop(columns=cocktail_df_exclude_cols)
cocktails_df.head()
# Out:
#    idDrink strDrink            strTags     strCategory strAlcoholic  \
# 0    17222       A1                NaN        Cocktail    Alcoholic
# 1    13501      ABC                NaN            Shot    Alcoholic
# 2    17225      Ace                NaN        Cocktail    Alcoholic
# 3    14610     ACID                NaN            Shot    Alcoholic
# 4    17837     Adam  Alcoholic,Holiday  Ordinary Drink    Alcoholic
#
#          strGlass                                    strInstructions  \
# 0  Cocktail glass  Pour all ingredients into a cocktail shaker, m...
# 1      Shot glass                           Layered in a shot glass.
# 2   Martini Glass  Shake all the ingredients in a cocktail shaker...
# 3      Shot glass  Poor in the 151 first followed by the 101 serv...
# 4  Cocktail glass  In a shaker half-filled with ice cubes, combin...
#
#        dateModified
# 0    9/7/2017 21:42
# 1   8/31/2016 19:32
# 2    9/7/2017 22:05
# 3  11/15/2016 11:28
# 4    9/2/2016 11:29

# %%
#ingredients table
ingredients_list = ['idDrink'] + ingredients_list
ingredients_df = df[ingredients_list]
ingredients_df.head()
# Out:
#    idDrink strIngredient1       strIngredient2 strIngredient3 strIngredient4  \
# 0    17222            Gin        Grand Marnier    Lemon Juice      Grenadine
# 1    13501       Amaretto  Baileys irish cream         Cognac            NaN
# 2    17225            Gin            Grenadine    Heavy cream           Milk
# 3    14610  151 proof rum          Wild Turkey            NaN            NaN
# 4    17837       Dark rum          Lemon juice      Grenadine            NaN
#
#   strIngredient5 strIngredient6 strIngredient7 strIngredient8 strIngredient9  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2      Egg White            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#   strIngredient10 strIngredient11
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
#Measures table
measures_list = ['idDrink'] + measures_list
measures_df = df[measures_list]
measures_df.head()
# Out:
#    idDrink  idDrink  idDrink strIngredient1       strIngredient2  \
# 0    17222    17222    17222            Gin        Grand Marnier
# 1    13501    13501    13501       Amaretto  Baileys irish cream
# 2    17225    17225    17225            Gin            Grenadine
# 3    14610    14610    14610  151 proof rum          Wild Turkey
# 4    17837    17837    17837       Dark rum          Lemon juice
#
#   strIngredient3 strIngredient4 strIngredient5 strIngredient6 strIngredient7  \
# 0    Lemon Juice      Grenadine            NaN            NaN            NaN
# 1         Cognac            NaN            NaN            NaN            NaN
# 2    Heavy cream           Milk      Egg White            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4      Grenadine            NaN            NaN            NaN            NaN
#
#   strIngredient8 strIngredient9 strIngredient10 strIngredient11
# 0            NaN            NaN             NaN             NaN
# 1            NaN            NaN             NaN             NaN
# 2            NaN            NaN             NaN             NaN
# 3            NaN            NaN             NaN             NaN
# 4            NaN            NaN             NaN             NaN
